# %%
import pandas as pd

# %%
# 🎯 Objective
# Load all datasets and inspect them deeply

# 🧠 What You Need To Do (Think First)
# Before writing code, ask yourself:

# What columns exist?

# Are there missing values?

# Are data types correct?

# Any obvious issues?

# %%
#load all files 
orders=pd.read_csv("raw_data/orders.csv")
customers=pd.read_csv("raw_data/customers.csv")
products=pd.read_csv("raw_data/products.csv")
payments=pd.read_csv("raw_data/payments.csv")

# %%
#Quick inspections 
print(orders.head())
print(orders.info())
print(orders.describe())
# Out:
#    order_id customer_id  order_date product_id  quantity   price
# 0      1001        C001  2024-01-05       P101       2.0   500.0
# 1      1002        C002  2024/01/06       P102       1.0  1200.0
# 2      1003        C003  05-01-2024       P103       NaN   700.0
# 3      1004        C001  2024-01-07       P101       1.0   500.0
# 4      1005        C004  2024-01-08       P104       3.0     NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     9 non-null      int64
#  1   customer_id  9 non-null      str
#  2   order_date   9 non-null      str
#  3   product_id   9 non-null      str
#  4   quantity     8 non-null      float64
#  5   price        8 non-null      float64
# dtypes: float64(2), int64(1), str(3)
# memory usage: 564.0 bytes
# None
#           order_id  quantity        price
# count     9.000000  8.000000     8.000000
# mean   1004.888889  2.500000   587.500000
# std       2.571208  1.690309   421.519361
# min    1001.000000  1.000000   150.000000
# 25%    1003.000000  1.000000   262.500000
# 50%    1005.000000  2.000000   500.000000
# 75%    1007.000000  3.500000   825.000000
# max    1008.000000  5.000000  1200.000000
